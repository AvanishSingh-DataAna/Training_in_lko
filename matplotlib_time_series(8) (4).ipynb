# %%
import pandas as pd
from datetime import datetime, timedelta
from matplotlib import pyplot as plt
from matplotlib import dates as dt

# %%
plt.style.use('seaborn')

dates = [
    datetime(2019, 5, 24),
    datetime(2019, 5, 25),
    datetime(2019, 5, 26),
    datetime(2019, 5, 27),
    datetime(2019, 5, 28),
    datetime(2019, 5, 29),
    datetime(2019, 5, 30)
]

y = [0, 1, 3, 4, 6, 5, 7]

plt.plot_date(dates, y)
plt.tight_layout()
plt.show()

# %%
# to show the lines just pas linestyle='solid

plt.style.use('seaborn')

dates = [
    datetime(2019, 5, 24),
    datetime(2019, 5, 25),
    datetime(2019, 5, 26),
    datetime(2019, 5, 27),
    datetime(2019, 5, 28),
    datetime(2019, 5, 29),
    datetime(2019, 5, 30)
]

y = [0, 1, 3, 4, 6, 5, 7]

plt.plot_date(dates,y, linestyle='solid')
plt.tight_layout()
plt.show()

# %%
# to make this plot much more attractive 

plt.style.use('seaborn')

dates = [
    datetime(2019, 5, 24),
    datetime(2019, 5, 25),
    datetime(2019, 5, 26),
    datetime(2019, 5, 27),
    datetime(2019, 5, 28),
    datetime(2019, 5, 29),
    datetime(2019, 5, 30)
]

y = [0, 1, 3, 4, 6, 5, 7]

plt.plot_date(dates,y, linestyle='solid')

plt.gcf().autofmt_xdate()  #gcf is method on figure.gcf(git current figure) 
plt.tight_layout()
plt.show()

# %%
# if you want to apply some more formatting on your date values use matplotlib date module.

plt.style.use('seaborn')

dates = [
    datetime(2019, 5, 24),
    datetime(2019, 5, 25),
    datetime(2019, 5, 26),
    datetime(2019, 5, 27),
    datetime(2019, 5, 28),
    datetime(2019, 5, 29),
    datetime(2019, 5, 30)
]

y = [0, 1, 3, 4, 6, 5, 7]

plt.plot_date(dates,y, linestyle='solid')

plt.gcf().autofmt_xdate()

date_format = dt.DateFormatter('%b, %d, %y')  # %b is showing date month in str.
plt.gca().xaxis.set_major_formatter(date_format)

plt.tight_layout()
plt.show()

# %%
plt.style.use('seaborn')

data = pd.read_csv('D:/matplotlib/time_series_matplot.csv')

price_date = data['Date']
price_close = data['Close']

plt.plot_date(price_date, price_close, linestyle='solid')

plt.gcf().autofmt_xdate()

plt.title('Bitcoin Prices')
plt.xlabel('Date')
plt.ylabel('Closing Price')

plt.tight_layout()
plt.show()

# %%
# suppose if i have tries to make some change in my date column. it does not performing right.
# because my csv data date format is in str type not in date type.
# as you can see in the below example if i add a new date at the bottom of our csv data.

plt.style.use('seaborn')

data = pd.read_csv('D:/matplotlib/time_series_matplot2.csv')

price_date = data['Date']
price_close = data['Close']

plt.plot_date(price_date, price_close, linestyle='solid')

plt.gcf().autofmt_xdate()

plt.title('Bitcoin Prices')
plt.xlabel('Date')
plt.ylabel('Closing Price')

plt.tight_layout()
plt.show()

# %%
# as you can see 17-05-2019 is showing at the end,it must have been at the front.bcz it in str currently

plt.style.use('seaborn')

data = pd.read_csv('D:/matplotlib/time_series_matplot2.csv')

data['Date'] = pd.to_datetime(data['Date'])
data.sort_values('Date', inplace=True)


price_date = data['Date']
price_close = data['Close']

plt.plot_date(price_date, price_close, linestyle='solid')

plt.gcf().autofmt_xdate()

plt.title('Bitcoin Prices')
plt.xlabel('Date')
plt.ylabel('Closing Price')

plt.tight_layout()
plt.show()

# %%
ndf = pd.read_csv('D:/pandas/apple_dataset.csv', parse_dates=['Date'], index_col='Date')
ndf
# Out:
#               Open      High     Low   Close    Volume
# Date
# 2010-04-01  213.43  214.5000  212.38  214.01  17633200
# 2010-05-01  214.60  215.5900  213.25  214.38  21496600
# 2010-06-01  214.38  215.2300  210.75  210.97  19720000
# 2010-07-01  211.75  212.0000  209.05  210.58  17040400
# 2010-08-01  210.30  212.0000  209.06  211.98  15986100
# ...            ...       ...     ...     ...       ...
# 2016-12-23  115.59  116.5200  115.59  116.52  14249484
# 2016-12-27  116.52  117.8000  116.49  117.26  18296855
# 2016-12-28  117.52  118.0166  116.20  116.76  20905892
# 2016-12-29  116.45  117.1095  116.40  116.73  15039519
# 2016-12-30  116.65  117.2000  115.43  115.82  30586265
#
# [1762 rows x 5 columns]

# %%
#ndf['Date'] = pd.to_datetime(ndf['Date'])
# ndf.set_index('Date')

# %%
ndf = ndf.sort_index()
ndf
# Out:
#               Open      High     Low   Close    Volume
# Date
# 2010-01-02  192.37  196.0000  191.30  194.73  26781300
# 2010-01-03  205.75  209.5000  205.45  208.99  19646200
# 2010-01-04  237.49  238.7300  232.75  235.97  21540900
# 2010-01-06  259.69  265.9400  258.96  260.83  31302600
# 2010-01-07  254.30  254.8000  243.22  248.48  36532000
# ...            ...       ...     ...     ...       ...
# 2016-12-23  115.59  116.5200  115.59  116.52  14249484
# 2016-12-27  116.52  117.8000  116.49  117.26  18296855
# 2016-12-28  117.52  118.0166  116.20  116.76  20905892
# 2016-12-29  116.45  117.1095  116.40  116.73  15039519
# 2016-12-30  116.65  117.2000  115.43  115.82  30586265
#
# [1762 rows x 5 columns]

# %%
ndf2 = ndf.reset_index()
ndf2
# Out:
#            Date    Open      High     Low   Close    Volume
# 0    2010-01-02  192.37  196.0000  191.30  194.73  26781300
# 1    2010-01-03  205.75  209.5000  205.45  208.99  19646200
# 2    2010-01-04  237.49  238.7300  232.75  235.97  21540900
# 3    2010-01-06  259.69  265.9400  258.96  260.83  31302600
# 4    2010-01-07  254.30  254.8000  243.22  248.48  36532000
# ...         ...     ...       ...     ...     ...       ...
# 1757 2016-12-23  115.59  116.5200  115.59  116.52  14249484
# 1758 2016-12-27  116.52  117.8000  116.49  117.26  18296855
# 1759 2016-12-28  117.52  118.0166  116.20  116.76  20905892
# 1760 2016-12-29  116.45  117.1095  116.40  116.73  15039519
# 1761 2016-12-30  116.65  117.2000  115.43  115.82  30586265
#
# [1762 rows x 6 columns]

# %%
ndf2 = ndf2.set_index('Date')

# %%
ndf2
# Out:
#               Open      High     Low   Close    Volume
# Date
# 2010-01-02  192.37  196.0000  191.30  194.73  26781300
# 2010-01-03  205.75  209.5000  205.45  208.99  19646200
# 2010-01-04  237.49  238.7300  232.75  235.97  21540900
# 2010-01-06  259.69  265.9400  258.96  260.83  31302600
# 2010-01-07  254.30  254.8000  243.22  248.48  36532000
# ...            ...       ...     ...     ...       ...
# 2016-12-23  115.59  116.5200  115.59  116.52  14249484
# 2016-12-27  116.52  117.8000  116.49  117.26  18296855
# 2016-12-28  117.52  118.0166  116.20  116.76  20905892
# 2016-12-29  116.45  117.1095  116.40  116.73  15039519
# 2016-12-30  116.65  117.2000  115.43  115.82  30586265
#
# [1762 rows x 5 columns]

# %%
tot_open_y = ndf2["2010":"2017"].Open.resample('Y').sum()
df5 = pd.DataFrame(tot_open_y, )
df5 = df5.reset_index()
df5
# Out:
#         Date         Open
# 0 2010-12-31   65506.7115
# 1 2011-12-31   91745.5071
# 2 2012-12-31  144162.9193
# 3 2013-12-31  119228.2552
# 4 2014-12-31   74375.9264
# 5 2015-12-31   30282.6400
# 6 2016-12-31   26335.3100

# %%
plt.style.use("default")
plt.plot_date(df5.Date,df5.Open, linestyle='solid')
plt.show()

# %%
tdf.index
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-ac241d51fd0b> in <module>
# ----> 1 tdf.index
#
# NameError: name 'tdf' is not defined

# %%
tdf.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-f14e8b3ac0eb> in <module>
# ----> 1 tdf.columns
#
# NameError: name 'tdf' is not defined

# %%
plt.figure()
plt.plot_date(tdf.index,tdf.Open, linestyle='solid')

plt.gcf().autofmt_xdate()

plt.title(' Apple Opening Stocks Vs Year')
plt.xlabel('Date')
plt.ylabel('Open Stock')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-cf7f35b7cb92> in <module>
#       1 plt.figure()
# ----> 2 plt.plot_date(tdf.index,tdf.Open, linestyle='solid')
#       3
#       4 plt.gcf().autofmt_xdate()
#       5
#
# NameError: name 'tdf' is not defined

# %%
ndf2
# Out:
#               Open      High     Low   Close    Volume
# Date
# 2010-01-02  192.37  196.0000  191.30  194.73  26781300
# 2010-01-03  205.75  209.5000  205.45  208.99  19646200
# 2010-01-04  237.49  238.7300  232.75  235.97  21540900
# 2010-01-06  259.69  265.9400  258.96  260.83  31302600
# 2010-01-07  254.30  254.8000  243.22  248.48  36532000
# ...            ...       ...     ...     ...       ...
# 2016-12-23  115.59  116.5200  115.59  116.52  14249484
# 2016-12-27  116.52  117.8000  116.49  117.26  18296855
# 2016-12-28  117.52  118.0166  116.20  116.76  20905892
# 2016-12-29  116.45  117.1095  116.40  116.73  15039519
# 2016-12-30  116.65  117.2000  115.43  115.82  30586265
#
# [1762 rows x 5 columns]

# %%
abc = ndf2['2012-04-01':'2013-03-31'].Close.resample('M').sum()
abc
# Out:
# Date
# 2012-04-30    11185.3854
# 2012-05-31    12467.4284
# 2012-06-30    12529.7450
# 2012-07-31    12322.5759
# 2012-08-31    13808.9080
# 2012-09-30    13337.7910
# 2012-10-31    12023.7204
# 2012-11-30    11945.9474
# 2012-12-31    11402.1278
# 2013-01-31     9852.1910
# 2013-02-28     8323.3720
# 2013-03-31     9234.7939
# Freq: M, Name: Close, dtype: float64

# %%
# %matplotlib inline
plt.plot(ndf2)

# %%
df6 = pd.DataFrame(abc)
df6
# Out:
#                  Close
# Date
# 2012-04-30  11185.3854
# 2012-05-31  12467.4284
# 2012-06-30  12529.7450
# 2012-07-31  12322.5759
# 2012-08-31  13808.9080
# 2012-09-30  13337.7910
# 2012-10-31  12023.7204
# 2012-11-30  11945.9474
# 2012-12-31  11402.1278
# 2013-01-31   9852.1910
# 2013-02-28   8323.3720
# 2013-03-31   9234.7939

# %%
plt.figure(figsize=(8,6))
plt.plot_date(df6.index, df6.Close, linestyle='solid')
plt.gcf().autofmt_xdate()
date_format = dt.DateFormatter('%b, %y')  # %b is showing date month in str.
plt.gca().xaxis.set_major_formatter(date_format)
plt.xticks(ticks=df6.index, label = date_format)
plt.grid()
plt.show()

# %%
bcd = ndf2['2013-04-01':'2014-03-31'].Close.resample('M').sum()
bcd
# Out:
# Date
# 2013-04-30     9280.0840
# 2013-05-31    10427.0140
# 2013-06-30     8803.2650
# 2013-07-31     9451.9860
# 2013-08-31    11164.4520
# 2013-09-30     9518.5580
# 2013-10-31    11049.0515
# 2013-11-30    11105.3180
# 2013-12-31    10893.8900
# 2014-01-31     9032.3920
# 2014-02-28     8577.2700
# 2014-03-31    10205.8500
# Freq: M, Name: Close, dtype: float64

# %%
df7 = pd.DataFrame(bcd)
df7
# Out:
#                  Close
# Date
# 2013-04-30   9280.0840
# 2013-05-31  10427.0140
# 2013-06-30   8803.2650
# 2013-07-31   9451.9860
# 2013-08-31  11164.4520
# 2013-09-30   9518.5580
# 2013-10-31  11049.0515
# 2013-11-30  11105.3180
# 2013-12-31  10893.8900
# 2014-01-31   9032.3920
# 2014-02-28   8577.2700
# 2014-03-31  10205.8500

# %%
plt.figure(figsize=(8,7))
plt.plot_date(df7.index, df7.Close, linestyle='dashed')
plt.gcf().autofmt_xdate()
date_format = dt.DateFormatter('%b,%y')
plt.gca().xaxis.set_major_formatter(date_format)
plt.xticks(ticks=df7.index, label=date_format)
plt.grid()
plt.show()

# %%
# %matplotlib inline
tdf.plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-7460a549d73b> in <module>
#       1 get_ipython().run_line_magic('matplotlib', 'inline')
# ----> 2 tdf.plot()
#
# NameError: name 'tdf' is not defined

# %%
plt.plot_date(tdf.index, linestyle='solid')

plt.gcf().autofmt_xdate()

plt.title('Bitcoin Prices')
plt.xlabel('Date')
plt.ylabel('Closing Price')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-a66770e1740f> in <module>
# ----> 1 plt.plot_date(tdf.index, linestyle='solid')
#       2
#       3 plt.gcf().autofmt_xdate()
#       4
#       5 plt.title('Bitcoin Prices')
#
# NameError: name 'tdf' is not defined

# %%
df6 =
# Out:
#   File "<ipython-input-32-6938da433390>", line 1
#     df7 =
#           ^
# SyntaxError: invalid syntax

# %%
fig, (ax1, ax2) = plt.subplot(nrows=2, ncols=1)
ax1.plot_date(df6.index, df6.Close, linestyle='solid')
ax2.plot_date(df6.index, df6.Close, linestyle='solid')
plt.gcf().autofmt_xdate()
date_format = dt.DateFormatter('%b, %y')  # %b is showing date month in str.
plt.gca().xaxis.set_major_formatter(date_format)
plt.xticks(ticks=df6.index, label = date_format)
plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-a3c8915d6f82> in <module>
# ----> 1 fig, (ax1, ax2) = plt.subplot(nrows=2, ncols=1)
#       2 ax1.plot_date(df6.index, df6.Close, linestyle='solid')
#       3 ax2.plot_date(df6.index, df6.Close, linestyle='solid')
#       4 plt.gcf().autofmt_xdate()
#       5 date_format = dt.DateFormatter('%b, %y')  # %b is showing date month in str.
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in subplot(*args, **kwargs)
#    1136     # Check for nrows and ncols, which are not valid subplot args:
#    1137     if 'nrows' in kwargs or 'ncols' in kwargs:
# -> 1138         raise TypeError("subplot() got an unexpected keyword argument 'ncols' "
#    1139                         "and/or 'nrows'.  Did you intend to call subplots()?")
#    1140
#
# ...
