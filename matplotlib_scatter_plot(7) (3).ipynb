# %%
from matplotlib import pyplot as plt
import pandas as pd
import seaborn as sns

# %%
tdf = sns.load_dataset('titanic')
tdf
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
plt.style.use('fivethirtyeight')
m = tdf.query("sex=='male'")

plt.scatter(m['fare'],m['age'])

plt.xlabel('Fare',fontsize=20)
plt.ylabel('Age',fontsize=20)
plt.title('Age vs Fare(Males)',fontsize=20)
plt.show()

# %%
x = tdf.query("fare>=400")
x
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 258         1       1  female  35.0      0      0  512.3292        C  First
# 679         1       1    male  36.0      0      1  512.3292        C  First
# 737         1       1    male  35.0      0      0  512.3292        C  First
#
#        who  adult_male deck embark_town alive  alone
# 258  woman       False  NaN   Cherbourg   yes   True
# 679    man        True    B   Cherbourg   yes  False
# 737    man        True    B   Cherbourg   yes   True

# %%
m = tdf.query("sex=='male'")
f = tdf.query("sex=='female'")
plt.scatter(m['fare'],m['age'],color='darkblue', label='Male')
plt.scatter(f['fare'],f['age'],color='pink', label='female')
plt.xlabel('Fare',fontsize=20)
plt.ylabel('Age',fontsize=20)
plt.title('Age vs Fare(Males)',fontsize=20)
plt.legend(bbox_to_anchor=(1.02,1), loc='upper right')
plt.show()

# %%
plt.style.use('fivethirtyeight')
plt.figure(figsize=(8,6))
male = titanic.query("sex=='male'")
female = titanic.query("sex=='female'")
plt.scatter(male['fare'],male['age'], label="Male", color='Slateblue')
plt.scatter(female['fare'],female['age'],label='Female',color='skyblue')
plt.xlabel('Fare')
plt.ylabel('Age')
plt.legend(bbox_to_anchor=(1.05,1),loc='upper right')
plt.show()

# %%
plt.style.use('fivethirtyeight')
plt.figure(figsize=(8,6))
male = titanic.query("sex=='male'")
female = titanic.query("sex=='female'")
plt.scatter(male['age'],male['survived'], label="Male", color='Slateblue')
plt.scatter(female['age'],female['survived'],label='Female',color='skyblue')
plt.xlabel('Age')
plt.ylabel('Survived')
plt.legend()
plt.show()

# %%
plt.style.use('seaborn')

x = [5, 7, 8, 5, 6, 7, 9, 2, 3, 4, 4, 4, 2, 6, 3, 6, 8, 6, 4, 1]
y = [7, 4, 3, 9, 1, 3, 2, 5, 2, 4, 8, 7, 1, 6, 4, 9, 7, 7, 5, 1]

plt.scatter(x,y)

plt.tight_layout()

plt.show()

# %%
plt.style.use('seaborn')

x = [5, 7, 8, 5, 6, 7, 9, 2, 3, 4, 4, 4, 2, 6, 3, 6, 8, 6, 4, 1]
y = [7, 4, 3, 9, 1, 3, 2, 5, 2, 4, 8, 7, 1, 6, 4, 9, 7, 7, 5, 1]

plt.scatter(x,y,s=200, c="green")  # s denots the sizes of dots.


plt.tight_layout()

plt.show()

# %%
plt.style.use('seaborn')

x = [5, 7, 8, 5, 6, 7, 9, 2, 3, 4, 4, 4, 2, 6, 3, 6, 8, 6, 4, 1]
y = [7, 4, 3, 9, 1, 3, 2, 5, 2, 4, 8, 7, 1, 6, 4, 9, 7, 7, 5, 1]

plt.scatter(x,y,s=200, c="green",edgecolor='black', linewidth=1, alpha=0.75)  # s denots the sizes of dots.


plt.tight_layout()

plt.show()

# %%
# suppose i have one more column and i want show that in this plot with different color

plt.style.use('seaborn')

x = [5, 7, 8, 5, 6, 7, 9, 2, 3, 4, 4, 4, 2, 6, 3, 6, 8, 6, 4, 1]
y = [7, 4, 3, 9, 1, 3, 2, 5, 2, 4, 8, 7, 1, 6, 4, 9, 7, 7, 5, 1]
z = [7, 5, 9, 7, 5, 7, 2, 5, 3, 7, 1, 2, 8, 1, 9, 2, 5, 6, 7, 5]
plt.scatter(x, y, s=100, c=z, edgecolor='black', linewidth=1, alpha=0.75)  # s denots the sizes of dots.


plt.tight_layout()

plt.show()

# %%
# these are the default colors, suppose if i want to change these colors i can use cmap attribute.

plt.style.use('seaborn')

x = [5, 7, 8, 5, 6, 7, 9, 2, 3, 4, 4, 4, 2, 6, 3, 6, 8, 6, 4, 1]
y = [7, 4, 3, 9, 1, 3, 2, 5, 2, 4, 8, 7, 1, 6, 4, 9, 7, 7, 5, 1]
z = [7, 5, 9, 7, 5, 7, 2, 5, 3, 7, 1, 2, 8, 1, 9, 2, 5, 6, 7, 5]
plt.scatter(x, y, s=100, c=z, cmap='Greens', edgecolor='black', linewidth=1, alpha=0.75)  


plt.tight_layout()

plt.show()

# %%
# you can also show your plot on the bases of different dot sizes

plt.style.use('seaborn')

x = [5, 7, 8, 5, 6, 7, 9, 2, 3, 4, 4, 4, 2, 6, 3, 6, 8, 6, 4, 1]
y = [7, 4, 3, 9, 1, 3, 2, 5, 2, 4, 8, 7, 1, 6, 4, 9, 7, 7, 5, 1]

z = [7, 5, 9, 7, 5, 7, 2, 5, 3, 7, 1, 2, 8, 1, 9, 2, 5, 6, 7, 5]

plt.scatter(x, y, s=100, c=z, cmap='Greens', edgecolor='black', linewidth=1, alpha=0.75)  

cbar = plt.colorbar()
cbar.set_label('Satisfaction')
plt.tight_layout()

plt.show()

# %%
plt.scatter(tdf.age, tdf.sibsp, c=tdf.fare, cmap='summer', edgecolor='black')
cbar = plt.colorbar()
cbar.set_label('Just for fun')
plt.tight_layout()

plt.show()

# %%
tdf
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
m1 = [90,55,89,40,76,64,81,23,66,40]
m2 = [88,33,90,78,20,30,76,50,89,22]
r = [9,4,8,7,3,5,8,2,7,1]

plt.scatter(m1, m2, c=r, cmap='spring', edgecolor='black', linewidth=1, alpha=0.75)
cbar = plt.colorbar()
cbar.set_label('Marking')
plt.tight_layout()

plt.show()

# %%
# the data is much meaningful so we can add labels to the data

plt.style.use('seaborn')

x = [5, 7, 8, 5, 6, 7, 9, 2, 3, 4, 4, 4, 2, 6, 3, 6, 8, 6, 4, 1]
y = [7, 4, 3, 9, 1, 3, 2, 5, 2, 4, 8, 7, 1, 6, 4, 9, 7, 7, 5, 1]

z = [7, 5, 9, 7, 5, 7, 2, 5, 3, 7, 1, 2, 8, 1, 9, 2, 5, 6, 7, 5]

sizes = [209, 486, 381, 255, 191, 315, 185, 228, 174,
         538, 239, 394, 399, 153, 273, 293, 436, 501, 397, 539]
plt.scatter(x, y, s=sizes, c=z, cmap='Greens', edgecolor='black', linewidth=1, alpha=0.75)  

cbar = plt.colorbar()
cbar.set_label('Satisfaction')
plt.tight_layout()

plt.show()

# %%
# top 200 trending videos on any day
# i want to draw the scatter plot on total views and total likes
# ration of likes to dislikes too.

# %%
data = pd.read_csv('D:/matplotlib/trending_data_scatterplot.csv')
view_count = data['view_count']
likes = data['likes']
ratio = data['ratio']
plt.scatter(view_count, likes, edgecolor='black', linewidth=1, alpha=0.75)

plt.title('Trending YouTube Videos')
plt.xlabel('View Count')
plt.ylabel('Total Likes')

plt.tight_layout()
plt.show()

# %%
plt.style.use('seaborn')
df = pd.read_csv('D:/matplotlib/trending_data_scatterplot.csv')

plt.scatter(df.view_count, df.likes, edgecolor='black', linewidth=1, alpha=0.75)

plt.xscale('log')
plt.yscale('log')

plt.title('Trending YouTube Videos')
plt.xlabel('View Count')
plt.ylabel('Total Likes')

plt.tight_layout()
plt.show()

# %%
# ratio of likes and dislikes

data = pd.read_csv('D:/matplotlib/trending_data_scatterplot.csv')
view_count = data['view_count']
likes = data['likes']
ratio = data['ratio']
plt.scatter(view_count, likes, c=ratio, cmap="summer", edgecolor='black', linewidth=1, alpha=0.75)

cbar = plt.colorbar()
cbar.set_label('like/dislike ratio')

plt.xscale('log')
plt.yscale('log')

plt.title('Trending YouTube Videos')
plt.xlabel('View Count')
plt.ylabel('Total Likes')

plt.tight_layout()
plt.show()

# %%
df = pd.read_csv('D:/matplotlib/trending_data_scatterplot.csv')

# %%
df
# Out:
#      view_count    likes  ratio
# 0       8036001   324742  96.91
# 1       9378067   562589  98.19
# 2       2182066   273650  99.38
# 3       6525864    94698  96.25
# 4       9481284   582481  97.22
# ..          ...      ...    ...
# 195     1069693     3970  90.66
# 196      590760    70454  99.18
# 197      319347     1208  92.50
# 198    27594927  1351963  96.40
# 199    26993425   437561  97.42
#
# [200 rows x 3 columns]

# %%
df.isnull().any()
# Out:
# view_count    False
# likes         False
# ratio         False
# dtype: bool

# %%
df.ratio>90
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 195    True
# 196    True
# 197    True
# 198    True
# 199    True
# Name: ratio, Length: 200, dtype: bool

# %%
df.loc[df['ratio']<=90].count()
# Out:
# view_count    22
# likes         22
# ratio         22
# dtype: int64

# %%
plt.style.use('fivethirtyeight')
plt.figure(figsize=(8,6))
plt.scatter(df.view_count, df.likes, edgecolor='black', linewidth=1, alpha=0.75)

plt.title('Trending YouTube Videos')
plt.xlabel('View Count')
plt.ylabel('Total Likes')

plt.tight_layout()
plt.show()

# %%
df
# Out:
#      view_count    likes  ratio
# 0       8036001   324742  96.91
# 1       9378067   562589  98.19
# 2       2182066   273650  99.38
# 3       6525864    94698  96.25
# 4       9481284   582481  97.22
# ..          ...      ...    ...
# 195     1069693     3970  90.66
# 196      590760    70454  99.18
# 197      319347     1208  92.50
# 198    27594927  1351963  96.40
# 199    26993425   437561  97.42
#
# [200 rows x 3 columns]

# %%
plt.style.use('fivethirtyeight')
plt.figure(figsize=(8,6))
plt.scatter(df.view_count, df.likes, edgecolor='black', linewidth=1, alpha=0.75)
plt.xscale('log')
plt.yscale('log')
plt.title('Trending YouTube Videos')
plt.xlabel('View Count')
plt.ylabel('Total Likes')

plt.tight_layout()
plt.show()

# %%
10*10*10*10*10*10
# Out:
# 1000000

# %%
plt.style.use('fivethirtyeight')
plt.figure(figsize=(8,6))
plt.scatter(df.likes, df.ratio, edgecolor='black', linewidth=1, alpha=0.75)
plt.xscale('log')

plt.title('Trending YouTube Videos')
plt.xlabel('Total likes')
plt.ylabel('Ratio')

plt.tight_layout()
plt.show()
